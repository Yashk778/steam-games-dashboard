# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# **WEB SCRAPING**

# %%
webpage =requests.get('https://store.steampowered.com/search/?category1=998').text

# %%
Soup = BeautifulSoup(webpage,'lxml')

# %%
print(Soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="responsive DesktopUI" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="#171a21" name="theme-color"/>
#   <title>
#    Steam Search
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=4Vj7bvhvv_UL&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=fNjyilod6jgc&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=u7ItYmj40jWH&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/css/v6/store.css?v=7I2JdcUuYsRY&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/css/v6/browse.css?v=ZWD2OrhO7eSv&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/css/v6/search.css?v=TqOGgK4VYgHm&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_responsive.css?v=8zUcJAgCg1Ml&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/jquery-1.8.3.min.js?v=NXam5zydzNu8&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $J = jQuery.noConflict();
#   </script>
#   <script type="text/javascript">
#    VALVE_PUBLIC_PATH = "https:\/\/store.akamai.steamstatic.com\/public\/";
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/tooltip.js?v=k5leO7MVvAaV&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/shared_global.js?v=K7zEIg1b7fg1&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/auth_refresh.js?v=w6QbwI-5-j2S&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/main.js?v=QJi1xvGAhCH-&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/dynamicstore.js?v=Ip2--85Texdk&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var __PrototypePreserve=[];
# 	__PrototypePreserve[0] = Array.from;
# 	__PrototypePreserve[1] = Array.prototype.filter;
# 	__PrototypePreserve[2] = Array.prototype.flatMap;
# 	__PrototypePreserve[3] = Array.prototype.find;
# 	__PrototypePreserve[4] = Array.prototype.some;
# 	__PrototypePreserve[5] = Function.prototype.bind;
# 	__PrototypePreserve[6] = HTMLElement.prototype.scrollTo;
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/prototype-1.7.js?v=npJElBnrEO6W&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Array.from = __PrototypePreserve[0] || Array.from;
# 	Array.prototype.filter = __PrototypePreserve[1] || Array.prototype.filter;
# 	Array.prototype.flatMap = __PrototypePreserve[2] || Array.prototype.flatMap;
# 	Array.prototype.find = __PrototypePreserve[3] || Array.prototype.find;
# 	Array.prototype.some = __PrototypePreserve[4] || Array.prototype.some;
# 	Function.prototype.bind = __PrototypePreserve[5] || Function.prototype.bind;
# 	HTMLElement.prototype.scrollTo = __PrototypePreserve[6] || HTMLElement.prototype.scrollTo;
#   </script>
#   <script type="text/javascript">
#    var __ScriptaculousPreserve=[];
# 	__ScriptaculousPreserve[0] = Array.from;
# 	__ScriptaculousPreserve[1] = Function.prototype.bind;
# 	__ScriptaculousPreserve[2] = HTMLElement.prototype.scrollTo;
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/scriptaculous/_combined.js?v=lz_99vci25ux&amp;l=english&amp;_cdn=akamai&amp;load=effects,controls,slider" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Array.from = __ScriptaculousPreserve[0] || Array.from;
# 	Function.prototype.bind = __ScriptaculousPreserve[1] || Function.prototype.bind;
# 	HTMLElement.prototype.scrollTo = __ScriptaculousPreserve[2] || HTMLElement.prototype.scrollTo;
# delete String['__parseStyleElement'];  Prototype.Browser.WebKit = true;
#   </script>
#   <script type="text/javascript">
#    Object.seal && [ Object, Array, String, Number ].map( function( builtin ) { Object.seal( builtin.prototype ); } );
#   </script>
#   <script type="text/javascript">
#    document.addEventListener('DOMContentLoaded', function(event) {
# 				$J.data( document, 'x_readytime', new Date().getTime() );
# 				$J.data( document, 'x_oldref', GetNavCookie() );
# 				SetupTooltips( { tooltipCSSClass: 'store_tooltip'  } );
# 		});
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/dselect.js?v=w0CV_PAvw3UA&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/searchpage.js?v=7-TB-by1j9Hp&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/javascript/jquery.filter.js?v=DGFlsws4j4Jj&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <script src="https://store.akamai.steamstatic.com/public/shared/javascript/shared_responsive_adapter.js?v=htU2ZedfDXGF&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#   </script>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@steam" name="twitter:site"/>
#   <meta content="Steam Search" property="og:title"/>
#   <meta content="Steam Search" property="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="105386699540688" property="fb:app_id"/>
#   <meta content="Steam" property="og:site"/>
#   <link href="https://store.akamai.steamstatic.com/public/shared/images/responsive/steam_share_image.jpg" rel="image_src"/>
#   <meta content="https://store.akamai.steamstatic.com/public/shared/images/responsive/steam_share_image.jpg" property="og:image"/>
#   <meta content="https://store.akamai.steamstatic.com/public/shared/images/responsive/steam_share_image.jpg" name="twitter:image"/>
#   <meta content="https://store.akamai.steamstatic.com/public/shared/images/responsive/steam_share_image.jpg" property="og:image:secure"/>
#  </head>
#  <body class="v6 search_page widestore v7menu responsive_page">
#   <div class="responsive_page_frame with_header">
#    <div aria-label="Mobile Menu" class="responsive_page_menu_ctn mainmenu" role="navigation">
#     <div class="responsive_page_menu" id="responsive_page_menu">
#      <div class="mainmenu_contents">
#       <div class="mainmenu_contents_items">
#        <a class="menuitem" href="https://store.steampowered.com/login/?redir=search%2F%3Fcategory1%3D998&amp;redir_ssl=1&amp;snr=1_7_7_230_global-header">
#         Sign in
#        </a>
#        <a class="menuitem supernav supernav_active" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/?snr=1_7_7_230_global-responsive-menu">
#         Store
#        </a>
#        <div class="submenu_Store" data-submenuid="Store" style="display: none;">
#         <a class="submenuitem" href="https://store.steampowered.com/?snr=1_7_7_230_global-responsive-menu">
#          Home
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/explore/?snr=1_7_7_230_global-responsive-menu">
#          Discovery Queue
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
#          Wishlist
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/points/shop/?snr=1_7_7_230_global-responsive-menu">
#          Points Shop
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/news/?snr=1_7_7_230_global-responsive-menu">
#          News
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/stats/?snr=1_7_7_230_global-responsive-menu">
#          Charts
#         </a>
#        </div>
#        <a class="menuitem supernav" data-tooltip-content=".submenu_Community" data-tooltip-type="selector" href="https://steamcommunity.com/">
#         Community
#        </a>
#        <div class="submenu_Community" data-submenuid="Community" style="display: none;">
#         <a class="submenuitem" href="https://steamcommunity.com/">
#          Home
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/discussions/">
#          Discussions
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/workshop/">
#          Workshop
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/market/">
#          Market
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/?subsection=broadcasts">
#          Broadcasts
#         </a>
#        </div>
#        <a class="menuitem" href="https://store.steampowered.com/about/?snr=1_7_7_230_global-responsive-menu">
#         About
#        </a>
#        <a class="menuitem" href="https://help.steampowered.com/en/">
#         Support
#        </a>
#        <div class="minor_menu_items">
#         <div class="menuitem change_language_action">
#          Change language
#         </div>
#         <a class="menuitem" href="https://store.steampowered.com/mobile" rel="noreferrer" target="_blank">
#          Get the Steam Mobile App
#         </a>
#         <div class="menuitem" onclick="Responsive_RequestDesktopView();" role="link">
#          View desktop website
#         </div>
#        </div>
#       </div>
#       <div class="mainmenu_footer_spacer">
#       </div>
#       <div class="mainmenu_footer">
#        <div class="mainmenu_footer_logo">
#         <img src="https://store.akamai.steamstatic.com/public/shared/images/responsive/footerLogo_valve_new.png"/>
#        </div>
#        © Valve Corporation. All rights reserved. All trademarks are property of their respective owners in the US and other countries.
#        <span class="mainmenu_valve_links">
#         <a href="https://store.steampowered.com/privacy_agreement/?snr=1_7_7_230_global-responsive-menu" target="_blank">
#          Privacy Policy
#         </a>
#         |
#         <a href="http://www.valvesoftware.com/legal.htm" target="_blank">
#          Legal
#         </a>
#         |
#         <a href="https://help.steampowered.com/faqs/view/10BB-D27A-6378-4436" target="_blank">
#          Accessibility
#         </a>
#         |
#         <a href="https://store.steampowered.com/subscriber_agreement/?snr=1_7_7_230_global-responsive-menu" target="_blank">
#          Steam Subscriber Agreement
#         </a>
#         |
#         <a href="https://store.steampowered.com/steam_refunds/?snr=1_7_7_230_global-responsive-menu" target="_blank">
#          Refunds
#         </a>
#         |
#         <a href="https://store.steampowered.com/account/cookiepreferences/?snr=1_7_7_230_global-responsive-menu" target="_blank">
#          Cookies
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_local_menu_tab">
#    </div>
#    <div class="responsive_page_menu_ctn localmenu">
#     <div class="responsive_page_menu" data-panel='{"onOptionsActionDescription":"Filter","onOptionsButton":"Responsive_ToggleLocalMenu()","onCancelButton":"Responsive_ToggleLocalMenu()"}' id="responsive_page_local_menu">
#      <div class="localmenu_content" data-panel='{"maintainY":true,"bFocusRingRoot":true,"flow-children":"column"}'>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_header">
#     <div class="responsive_header_content">
#      <div id="responsive_menu_logo">
#       <img height="100%" src="https://store.akamai.steamstatic.com/public/shared/images/responsive/header_menu_hamburger.png"/>
#      </div>
#      <div class="responsive_header_logo">
#       <a href="https://store.steampowered.com/?snr=1_7_7_230_global-responsive-menu">
#        <img alt="STEAM" border="0" height="36" src="https://store.akamai.steamstatic.com/public/shared/images/responsive/header_logo.png"/>
#       </a>
#      </div>
#      <div class="responsive_header_react_target" data-featuretarget="store-menu-responsive-search">
#       <div class="responsive_header_react_placeholder">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="responsive_page_content_overlay">
#    </div>
#    <div class="responsive_fixonscroll_ctn nonresponsive_hidden">
#    </div>
#    <div class="responsive_page_content">
#     <div data-panel='{"flow-children":"row"}' id="global_header" role="banner">
#      <div class="content">
#       <div class="logo">
#        <span id="logo_holder">
#         <a aria-label="Link to the Steam Homepage" href="https://store.steampowered.com/?snr=1_7_7_230_global-header">
#          <img alt="Link to the Steam Homepage" height="44" src="https://store.akamai.steamstatic.com/public/shared/images/header/logo_steam.svg?t=962016" width="176"/>
#         </a>
#        </span>
#       </div>
#       <div aria-label="Global Menu" class="supernav_container" role="navigation">
#        <a class="menuitem supernav supernav_active" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/?snr=1_7_7_230_global-header">
#         STORE
#        </a>
#        <div class="submenu_Store" data-submenuid="Store" style="display: none;">
#         <a class="submenuitem" href="https://store.steampowered.com/?snr=1_7_7_230_global-header">
#          Home
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/explore/?snr=1_7_7_230_global-header">
#          Discovery Queue
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
#          Wishlist
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/points/shop/?snr=1_7_7_230_global-header">
#          Points Shop
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/news/?snr=1_7_7_230_global-header">
#          News
#         </a>
#         <a class="submenuitem" href="https://store.steampowered.com/stats/?snr=1_7_7_230_global-header">
#          Charts
#         </a>
#        </div>
#        <a class="menuitem supernav" data-tooltip-content=".submenu_Community" data-tooltip-type="selector" href="https://steamcommunity.com/">
#         COMMUNITY
#        </a>
#        <div class="submenu_Community" data-submenuid="Community" style="display: none;">
#         <a class="submenuitem" href="https://steamcommunity.com/">
#          Home
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/discussions/">
#          Discussions
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/workshop/">
#          Workshop
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/market/">
#          Market
#         </a>
#         <a class="submenuitem" href="https://steamcommunity.com/?subsection=broadcasts">
#          Broadcasts
#         </a>
#        </div>
#        <a class="menuitem" href="https://store.steampowered.com/about/?snr=1_7_7_230_global-header">
#         About
#        </a>
#        <a class="menuitem" href="https://help.steampowered.com/en/">
#         SUPPORT
#        </a>
#       </div>
#       <script type="text/javascript">
#        jQuery(function($) {
# 			$('#global_header .supernav').v_tooltip({'location':'bottom', 'destroyWhenDone': false, 'tooltipClass': 'supernav_content', 'offsetY':-6, 'offsetX': 1, 'horizontalSnap': 4, 'tooltipParent': '#global_header .supernav_container', 'correctForScreenSize': false});
# 		});
#       </script>
#       <div id="global_actions">
#        <div aria-label="Account Menu" id="global_action_menu" role="navigation">
#         <a class="header_installsteam_btn header_installsteam_btn_green" href="https://store.steampowered.com/about/?snr=1_7_7_230_global-header">
#          <div class="header_installsteam_btn_content">
#           Install Steam
#          </div>
#         </a>
#         <a class="global_action_link" href="https://store.steampowered.com/login/?redir=search%2F%3Fcategory1%3D998&amp;redir_ssl=1&amp;snr=1_7_7_230_global-header">
#          sign in
#         </a>
#         |
#         <span class="pulldown global_action_link" id="language_pulldown" onclick="ShowMenu( this, 'language_dropdown', 'right' );">
#          language
#         </span>
#         <div class="popup_block_new" id="language_dropdown" style="display: none;">
#          <div class="popup_body popup_menu">
#           <a class="popup_menu_item tight" href="?l=schinese&amp;category1=998" onclick="ChangeLanguage( 'schinese' ); return false;">
#            简体中文 (Simplified Chinese)
#           </a>
#           <a class="popup_menu_item tight" href="?l=tchinese&amp;category1=998" onclick="ChangeLanguage( 'tchinese' ); return false;">
#            繁體中文 (Traditional Chinese)
#           </a>
#           <a class="popup_menu_item tight" href="?l=japanese&amp;category1=998" onclick="ChangeLanguage( 'japanese' ); return false;">
#            日本語 (Japanese)
#           </a>
#           <a class="popup_menu_item tight" href="?l=koreana&amp;category1=998" onclick="ChangeLanguage( 'koreana' ); return false;">
#            한국어 (Korean)
#           </a>
#           <a class="popup_menu_item tight" href="?l=thai&amp;category1=998" onclick="ChangeLanguage( 'thai' ); return false;">
#            ไทย (Thai)
#           </a>
#           <a class="popup_menu_item tight" href="?l=bulgarian&amp;category1=998" onclick="ChangeLanguage( 'bulgarian' ); return false;">
#            Български (Bulgarian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=czech&amp;category1=998" onclick="ChangeLanguage( 'czech' ); return false;">
#            Čeština (Czech)
#           </a>
#           <a class="popup_menu_item tight" href="?l=danish&amp;category1=998" onclick="ChangeLanguage( 'danish' ); return false;">
#            Dansk (Danish)
#           </a>
#           <a class="popup_menu_item tight" href="?l=german&amp;category1=998" onclick="ChangeLanguage( 'german' ); return false;">
#            Deutsch (German)
#           </a>
#           <a class="popup_menu_item tight" href="?l=spanish&amp;category1=998" onclick="ChangeLanguage( 'spanish' ); return false;">
#            Español - España (Spanish - Spain)
#           </a>
#           <a class="popup_menu_item tight" href="?l=latam&amp;category1=998" onclick="ChangeLanguage( 'latam' ); return false;">
#            Español - Latinoamérica (Spanish - Latin America)
#           </a>
#           <a class="popup_menu_item tight" href="?l=greek&amp;category1=998" onclick="ChangeLanguage( 'greek' ); return false;">
#            Ελληνικά (Greek)
#           </a>
#           <a class="popup_menu_item tight" href="?l=french&amp;category1=998" onclick="ChangeLanguage( 'french' ); return false;">
#            Français (French)
#           </a>
#           <a class="popup_menu_item tight" href="?l=italian&amp;category1=998" onclick="ChangeLanguage( 'italian' ); return false;">
#            Italiano (Italian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=indonesian&amp;category1=998" onclick="ChangeLanguage( 'indonesian' ); return false;">
#            Bahasa Indonesia (Indonesian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=hungarian&amp;category1=998" onclick="ChangeLanguage( 'hungarian' ); return false;">
#            Magyar (Hungarian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=dutch&amp;category1=998" onclick="ChangeLanguage( 'dutch' ); return false;">
#            Nederlands (Dutch)
#           </a>
#           <a class="popup_menu_item tight" href="?l=norwegian&amp;category1=998" onclick="ChangeLanguage( 'norwegian' ); return false;">
#            Norsk (Norwegian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=polish&amp;category1=998" onclick="ChangeLanguage( 'polish' ); return false;">
#            Polski (Polish)
#           </a>
#           <a class="popup_menu_item tight" href="?l=portuguese&amp;category1=998" onclick="ChangeLanguage( 'portuguese' ); return false;">
#            Português (Portuguese - Portugal)
#           </a>
#           <a class="popup_menu_item tight" href="?l=brazilian&amp;category1=998" onclick="ChangeLanguage( 'brazilian' ); return false;">
#            Português - Brasil (Portuguese - Brazil)
#           </a>
#           <a class="popup_menu_item tight" href="?l=romanian&amp;category1=998" onclick="ChangeLanguage( 'romanian' ); return false;">
#            Română (Romanian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=russian&amp;category1=998" onclick="ChangeLanguage( 'russian' ); return false;">
#            Русский (Russian)
#           </a>
#           <a class="popup_menu_item tight" href="?l=finnish&amp;category1=998" onclick="ChangeLanguage( 'finnish' ); return false;">
#            Suomi (Finnish)
#           </a>
#           <a class="popup_menu_item tight" href="?l=swedish&amp;category1=998" onclick="ChangeLanguage( 'swedish' ); return false;">
#            Svenska (Swedish)
#           </a>
#           <a class="popup_menu_item tight" href="?l=turkish&amp;category1=998" onclick="ChangeLanguage( 'turkish' ); return false;">
#            Türkçe (Turkish)
#           </a>
#           <a class="popup_menu_item tight" href="?l=vietnamese&amp;category1=998" onclick="ChangeLanguage( 'vietnamese' ); return false;">
#            Tiếng Việt (Vietnamese)
#           </a>
#           <a class="popup_menu_item tight" href="?l=ukrainian&amp;category1=998" onclick="ChangeLanguage( 'ukrainian' ); return false;">
#            Українська (Ukrainian)
#           </a>
#           <a class="popup_menu_item tight" href="https://www.valvesoftware.com/en/contact?contact-person=Translation%20Team%20Feedback" target="_blank">
#            Report a translation problem
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="StoreMenuLoadingPlaceholder" data-featuretarget="store-menu-v7">
#      <div class="PlaceholderInner">
#      </div>
#     </div>
#     <div id="responsive_store_nav_ctn">
#     </div>
#     <div id="responsive_store_nav_overlay" style="display:none">
#      <div id="responsive_store_nav_overlay_ctn">
#      </div>
#      <div id="responsive_store_nav_overlay_bottom">
#      </div>
#     </div>
#     <div id="responsive_store_search_overlay" style="display:none">
#     </div>
#     <div data-cart-banner-spot="1">
#     </div>
#     <div class="responsive_page_template_content" data-panel='{"autoFocus":true,"navKey":"responsive_page_template_content"}' id="responsive_page_template_content" role="main">
#      <div data-broadcastuser='{"success":1,"bHideStoreBroadcast":false}' data-config='{"EUNIVERSE":1,"WEB_UNIVERSE":"public","LANGUAGE":"english","COUNTRY":"IN","MEDIA_CDN_COMMUNITY_URL":"https:\/\/cdn.akamai.steamstatic.com\/steamcommunity\/public\/","MEDIA_CDN_URL":"https:\/\/cdn.akamai.steamstatic.com\/","VIDEO_CDN_URL":"https:\/\/video.akamai.steamstatic.com\/","COMMUNITY_CDN_URL":"https:\/\/community.akamai.steamstatic.com\/","COMMUNITY_CDN_ASSET_URL":"https:\/\/cdn.akamai.steamstatic.com\/steamcommunity\/public\/assets\/","STORE_CDN_URL":"https:\/\/store.akamai.steamstatic.com\/","PUBLIC_SHARED_URL":"https:\/\/store.akamai.steamstatic.com\/public\/shared\/","COMMUNITY_BASE_URL":"https:\/\/steamcommunity.com\/","CHAT_BASE_URL":"https:\/\/steamcommunity.com\/","STORE_BASE_URL":"https:\/\/store.steampowered.com\/","STORE_CHECKOUT_BASE_URL":"https:\/\/checkout.steampowered.com\/","IMG_URL":"https:\/\/store.akamai.steamstatic.com\/public\/images\/","STEAMTV_BASE_URL":"https:\/\/steam.tv\/","HELP_BASE_URL":"https:\/\/help.steampowered.com\/","PARTNER_BASE_URL":"https:\/\/partner.steamgames.com\/","STATS_BASE_URL":"https:\/\/partner.steampowered.com\/","INTERNAL_STATS_BASE_URL":"https:\/\/steamstats.valve.org\/","IN_CLIENT":false,"USE_POPUPS":false,"STORE_ICON_BASE_URL":"https:\/\/shared.akamai.steamstatic.com\/store_item_assets\/steam\/apps\/","STORE_ITEM_BASE_URL":"https:\/\/shared.akamai.steamstatic.com\/store_item_assets\/","WEBAPI_BASE_URL":"https:\/\/api.steampowered.com\/","TOKEN_URL":"https:\/\/store.steampowered.com\/\/chat\/clientjstoken","BUILD_TIMESTAMP":1772832532,"PAGE_TIMESTAMP":1772866515,"IN_TENFOOT":false,"IN_GAMEPADUI":false,"IN_CHROMEOS":false,"IN_MOBILE_WEBVIEW":false,"PLATFORM":"unknown","BASE_URL_STORE_CDN_ASSETS":"https:\/\/cdn.akamai.steamstatic.com\/store\/","EREALM":1,"LOGIN_BASE_URL":"https:\/\/login.steampowered.com\/","AVATAR_BASE_URL":"https:\/\/avatars.akamai.steamstatic.com\/","FROM_WEB":true,"WEBSITE_ID":"Store","BASE_URL_SHARED_CDN":"https:\/\/shared.akamai.steamstatic.com\/","CLAN_CDN_ASSET_URL":"https:\/\/clan.akamai.steamstatic.com\/","COMMUNITY_ASSETS_BASE_URL":"https:\/\/shared.akamai.steamstatic.com\/community_assets\/","SUPPORT_BASE_URL":"https:\/\/steamsupport.valvesoftware.com\/","SNR":"1_7_7_230"}' data-hwinfo='{"bSteamOS":false,"bSteamDeck":false}' data-store_user_config='{"webapi_token":"","shoppingcart":null,"originating_navdata":{"domain":"store.steampowered.com","controller":"direct-navigation","method":"","submethod":"","feature":"","depth":0,"countrycode":"","webkey":null,"is_client":false,"curator_data":null,"is_likely_bot":true,"is_utm":false},"wishlist_item_count":0}' data-userinfo='{"logged_in":false,"country_code":"IN","excluded_content_descriptors":[3,4]}' id="application_config" style="display: none;">
#      </div>
#      <div id="application_root">
#      </div>
#      <script>
#       window.g_wapit="";
#      </script>
#      <link href="https://store.akamai.steamstatic.com/public/css/applications/store/main.css?v=S47KxFXzCFoN&amp;l=english&amp;_cdn=akamai" rel="stylesheet" type="text/css"/>
#      <script src="https://store.akamai.steamstatic.com/public/javascript/applications/store/manifest.js?v=gMlcqI8MngGN&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#      </script>
#      <script src="https://store.akamai.steamstatic.com/public/javascript/applications/store/libraries~b28b7af69.js?v=VXi50UIeX17k&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#      </script>
#      <script src="https://store.akamai.steamstatic.com/public/javascript/applications/store/main.js?v=kQl1Eh2xzkHA&amp;l=english&amp;_cdn=akamai" type="text/javascript">
#      </script>
#      <script type="text/javascript">
#       var g_AccountID = 0;
# 	var g_Languages = ["english"];
# 	var g_sessionID = "e12632ff6284d3430a9b0119";
# 	var g_ServerTime = 1772866515;
# 	var g_bUseNewCartAPI = true;
#
# 	$J( InitMiniprofileHovers( 'https%3A%2F%2Fstore.steampowered.com%2F' ) );
#
#
# 	if ( typeof GStoreItemData != 'undefined' )
# 	{
# 		GStoreItemData.AddNavParams({
# 			__page_default: "1_7_7_230",
# 			__page_default_obj: {"domain":"store.steampowered.com","controller":"search","method":"search","submethod":"browse","feature":null,"depth":null,"countrycode":"IN","webkey":null,"is_client":false,"curator_data":null,"is_likely_bot":true,"is_utm":null},
# 			__originating_obj: {"domain":"store.steampowered.com","controller":"direct-navigation","method":"","submethod":"","feature":"","depth":0,"countrycode":"","webkey":null,"is_client":false,"curator_data":null,"is_likely_bot":true,"is_utm":false},
# 			storemenu_recommendedtags: "1_7_7_230_17"		});
# 	}
#
# 	if ( typeof GDynamicStore != 'undefined' )
# 	{
# 		GDynamicStore.Init(0, false, "", {"primary_language":null,"secondary_languages":null,"platform_windows":null,"platform_mac":null,"platform_linux":null,"timestamp_updated":null,"hide_store_broadcast":null,"review_score_preference":null,"timestamp_content_descriptor_preferences_updated":null,"provide_deck_feedback":null,"additional_languages":null,"game_frame_rate_reporting":null}, 'IN',
# 			{"bNoDefaultDescriptors":true});
# 		GStoreItemData.SetCurrencyFormatter(function( nValueInCents, bWholeUnitsOnly ) { var fmt = function( nValueInCents, bWholeUnitsOnly ) {	var format = v_numberformat( nValueInCents / 100, bWholeUnitsOnly ? 0 : 2, ".", ",");format = format.replace( ".00", '' ); return format; };var strNegativeSymbol = '';return strNegativeSymbol + "\u20b9 " + fmt( nValueInCents, bWholeUnitsOnly );});
# 		GStoreItemData.SetCurrencyMinPriceIncrement(100);
# 	}
#      </script>
#      <script type="text/javascript">
#       jQuery( document ).ready(function( $ ) {
#
# 		// when we create the responsive right column menu, it moves several hidden inputs out of the form which breaks searching, so
# 		//	we reparent any hidden inputs in the right column to a spot at the bottom of the form with other hidden elements.
# 		// this selector only works once, so after moving from responsive to desktop mode the elements will stay in the hidden searchform area, but that's ok.
# 		//	they work just as well from there.
# 		Responsive_ReparentItemsInResponsiveMode( '#additional_search_options input[type=hidden]', $J('#hidden_searchform_elements') );
#
#
# 		var bInfiniScroll = true;
# 		var nItemCount = 142908;
#
#         if ( nItemCount > 0 && bInfiniScroll )
#         {
# 			InitInfiniteScroll.bEnabled = true;
# 			InitInfiniteScroll.nScrollSize = 50;
#         }
#
#         InitSearchPage();
#
# 		UpdateTags();
#
# 		InitAutocollapse();
#
# 		// Handle our user hitting 'back' cleanly. This needs to trigger after the Dynamic
# 		// Store has finished, or (if no dynamic store) just after the page renders.
# 		//
# 		// Dynamic Store will trigger its OnReady immediately if it's already complete.
# 		if ( GDynamicStore )
# 			GDynamicStore.OnReady( function() { setTimeout( HandleBackReposition, 500 ) } );
# 		else
# 			window.addEventListener( 'load', function() { setTimeout( HandleBackReposition, 500 ) } );
#
# 		// in the react native mobile app show the filter menu button next to the sort drop-down, and the croutons below those controls
# 			});
#      </script>
#      <div class="page_header_ctn search" data-panel='{"noFocusRing":true,"onOptionsActionDescription":"Filter","onOptionsButton":"Responsive_ToggleLocalMenu();"}'>
#       <div class="page_content">
#        <div class="breadcrumbs">
#        </div>
#        <h2 class="pageheader full">
#        </h2>
#        <div class="termcontainer">
#         <div id="termsnone">
#          <div class="pagesubheader">
#           All Products
#          </div>
#         </div>
#         <div class="searchtag" id="searchtag_tmpl" style="display: none">
#          <img class="search_crouton_icon"/>
#          <span class="label">
#          </span>
#          <a class="btn" href="#">
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <form action="https://store.steampowered.com/search/" id="advsearchform" method="GET" name="advsearchform" onsubmit="AjaxSearchResults(); return false;">
#       <!-- Main Background -->
#       <div class="page_content_ctn" data-panel='{"noFocusRing":true,"onOptionsActionDescription":"Filter","onOptionsButton":"Responsive_ToggleLocalMenu();"}'>
#        <div class="page_content" data-gpnav="columns">
#         <div class="leftcol large" data-gpnav="rows">
#          <div class="searchbar" data-gpnav="columns">
#           <div class="sortbox">
#            <div class="label">
#             Sort by
#            </div>
#            <div class="dselect_container" id="sort_by_dselect_container">
#             <input id="sort_by" name="sort_by" onchange="$J('sort_by').val(this.value); AjaxSearchResults(); " type="hidden" value="_ASC"/>
#             <button aria-controls="sort_by_droplist" aria-expanded="false" class="trigger" data-panel="{&quot;onGamepadDirection&quot;:&quot;return DSelectOnGamepadDirection( event, 'sort_by')&quot;,&quot;onOKButton&quot;:&quot;return DSelectOnOKButton( event, 'sort_by')&quot;,&quot;onCancelButton&quot;:&quot;return DSelectOnCancelButton( event, 'sort_by')&quot;}" href="javascript:DSelectNoop();" id="sort_by_trigger" onblur="DSelectOnBlur( 'sort_by');" onclick="DSelectOnTriggerClick('sort_by');" onfocus="DSelectOnFocus( 'sort_by');" role="combobox" type="button">
#              Relevance
#             </button>
#             <div class="dropcontainer" id="sort_by_listctn">
#              <ul class="dropdownhidden" data-panel="{&quot;bFocusRingRoot&quot;:true,&quot;onCancelButton&quot;:&quot;DSelectHide( 'sort_by')&quot;,&quot;flow-children&quot;:&quot;column&quot;}" id="sort_by_droplist" role="listbox">
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="_ASC" onclick="DHighlightItem( 'sort_by', 0, true );" onmouseover="DHighlightItem( 'sort_by', 0, false );" role="option" tabindex="99999">
#                 Relevance
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="Released_DESC" onclick="DHighlightItem( 'sort_by', 1, true );" onmouseover="DHighlightItem( 'sort_by', 1, false );" role="option" tabindex="99999">
#                 Release date
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="Name_ASC" onclick="DHighlightItem( 'sort_by', 2, true );" onmouseover="DHighlightItem( 'sort_by', 2, false );" role="option" tabindex="99999">
#                 Name
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="Price_ASC" onclick="DHighlightItem( 'sort_by', 3, true );" onmouseover="DHighlightItem( 'sort_by', 3, false );" role="option" tabindex="99999">
#                 Lowest Price
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="Price_DESC" onclick="DHighlightItem( 'sort_by', 4, true );" onmouseover="DHighlightItem( 'sort_by', 4, false );" role="option" tabindex="99999">
#                 Highest Price
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="Reviews_DESC" onclick="DHighlightItem( 'sort_by', 5, true );" onmouseover="DHighlightItem( 'sort_by', 5, false );" role="option" tabindex="99999">
#                 User Reviews
#                </a>
#               </li>
#               <li>
#                <a class="inactive_selection" data-panel='{"noFocusRing":true}' href="javascript:DSelectNoop();" id="DeckCompatDate_DESC" onclick="DHighlightItem( 'sort_by', 6, true );" onmouseover="DHighlightItem( 'sort_by', 6, false );" role="option" tabindex="99999">
#                 Steam Deck Compatibility Review Date
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <script language="javascript">
#             $J( function() { $J('#sort_by_dselect_container').on('keydown', HandleKeyDown ); });
#            </script>
#           </div>
#           <div class="searchbar_left">
#            <input class="text" data-gpnav="item" data-panel='{"autoFocus":true}' id="term" maxlength="64" name="displayterm" onblur="if(this.value==''){this.value='enter search term or tag';}" onchange="$('realterm').value= (this.value=='enter search term or tag') ? '' : this.value" onfocus="if(this.value=='enter search term or tag'){this.value=''}" type="text" value="enter search term or tag"/>
#            <input id="realterm" name="term" type="hidden" value=""/>
#            <input id="hide_filtered_results_warning" name="hide_filtered_results_warning" type="hidden" value=""/>
#            <input id="ignore_preferences" name="ignore_preferences" type="hidden" value=""/>
#            <input autocomplete="off" id="force_infinite" name="force_infinite" type="hidden" value=""/>
#            <button class="btnv6_blue_hoverfade btn_small" data-gpnav="item" type="submit">
#             <span>
#              Search
#             </span>
#            </button>
#            <div class="autocomplete" id="term_options" style="display: none;">
#            </div>
#           </div>
#           <div class="clear_ctn" style="clear: both;">
#           </div>
#          </div>
#          <script type="text/javascript">
#           new Ajax.Autocompleter( $('advsearchform').elements['displayterm'], 'term_options', 'https://store.steampowered.com/search/suggest', {frequency: 0.2, method: "get", paramName: 'term', parameters : 'cc=IN&realm=1&l=english&excluded_content_descriptors%5B0%5D=3&excluded_content_descriptors%5B1%5D=4', allowFreeEntry: true, afterUpdateElement:function() { $('realterm').value=$('term').value; AjaxSearchResults(); } });
#          </script>
#          <div class="search_results_filtered_warning collapsed" data-panel='{"type":"PanelGroup"}' id="search_results_filtered_warning_persistent">
#          </div>
#          <div class="search_results" data-gpnav="rows" id="search_results">
#           <script type="text/javascript">
#            $J( function() {
# 		PopulateTagFacetData( [[4182,"93365"],[492,"77977"],[19,"65322"],[597,"60795"],[21,"60542"],[3871,"49809"],[4191,"42718"],[4166,"32647"],[9,"31564"],[599,"31525"],[3834,"29615"],[4305,"29225"],[1664,"27698"],[122,"27064"],[3964,"26609"],[3839,"25573"],[1742,"25124"],[4726,"24210"],[1684,"23503"],[4106,"21652"],[1773,"20702"],[3993,"19437"],[3859,"19292"],[1667,"18471"],[4252,"18387"]], [], false );
# 		PopulateLangFilterData( ["english"], ["english"] );
# 		PopulateHWCompatFacetData( [[0,"115659"],[2,"15242"],[3,"7030"],[1,"4972"]], [[0,"116601"],[2,"23112"],[1,"3190"]], /* Show Parens */ 0, /*Show SteamOS Compat */ 0 );
# 	});
#           </script>
#           <div class="search_results_filtered_warning collapsed" id="search_results_filtered_warning">
#            <div>
#             142,908 results match your search. 6,972 titles have been excluded based on your preferences. However, none of these titles would appear on the first page of results.
#            </div>
#            <div class="settings_tab" data-panel='{"focusable":true,"clickOnActivate":true}' onclick="OnClickShowFilteredContentSettingsModal()" role="button">
#            </div>
#           </div>
#           <script>
#            g_strUnfilteredURL = 'https://store.steampowered.com/search/?category1=998&ignore_preferences=1';
#           </script>
#           <div id="search_result_container">
#            <div class="search_rule">
#            </div>
#            <!-- Extra empty div to hack around IE7 layout bug -->
#            <div>
#            </div>
#            <!-- End Extra empty div -->
#            <div data-panel='{"maintainY":true,"bFocusRingRoot":true,"flow-children":"column"}' id="search_resultsRows">
#             <!-- List Items -->
#             <a class="search_result_row ds_collapse_flag" data-ds-appid="2868840" data-ds-crtrids="[33974508]" data-ds-itemkey="App_2868840" data-ds-steam-deck-compat-handled="true" data-ds-tagids="[9,1716,1666,32322,791774,1091588,1685]" data-gpnav="item" data-search-page="1" href="https://store.steampowered.com/app/2868840/Slay_the_Spire_2/?snr=1_7_7_230_150_1" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:2868840,&quot;public&quot;:1,&quot;v6&quot;:1} );">
#              <div class="search_capsule">
#               <img src="https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2868840/fb0ad136e9eaa4297a1ab3440d88ecb7209f44a2/capsule_231x87.jpg?t=1772736015"/>
#              </div>
#              <div class="responsive_search_name_combined">
#               <div class="search_name ellipsis">
#                <span class="title">
#                 Slay the Spire 2
#                </span>
#               </div>
#               <div class="search_platforms">
#                <span class="platform_img win">
#                </span>
#                <span class="platform_img mac">
#                </span>
#                <span class="platform_img linux">
#                </span>
#               </div>
#               <div class="search_released responsive_secondrow">
#                5 Mar, 2026
#               </div>
#               <div class="search_reviewscore responsive_secondrow">
#                <span class="search_review_summary positive" data-tooltip-html="Overwhelmingly Positive&lt;br&gt;97% of the 7,768 user reviews for this game are positive.&lt;br&gt;&lt;br&gt;The review score for this product is calculated from reviews written in your language based on your preferences.">
#                </span>
#               </div>
#               <div class="search_price_discount_combined responsive_secondrow" data-price-final="110000">
#                <div class="search_discount_and_price responsive_secondrow">
#                 <div class="discount_block search_discount_block no_discount" data-bundlediscount="0" data-discount="0" data-price-final="110000">
#                  <div class="discount_prices">
#                   <div class="discount_final_price">
#                    ₹1,100.00
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="search_result_row ds_collapse_flag" data-ds-appid="3764200" data-ds-crtrids="[33273264,34827950]" data-ds-descids="[2,5]" data-ds-itemkey="App_3764200" data-ds-steam-deck-compat-handled="true" data-ds-tagids="[3978,1659,1667,3814,19,1663,3839]" data-gpnav="item" data-search-page="1" href="https://store.steampowered.com/app/3764200/Resident_Evil_Requiem/?snr=1_7_7_230_150_1" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:3764200,&quot;public&quot;:1,&quot;v6&quot;:1} );">
#              <div class="search_capsule">
#               <img src="https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3764200/64f506b9b6210df6055136e7017f2082957e5b22/capsule_231x87.jpg?t=1772587704"/>
#              </div>
#              <div class="responsive_search_name_combined">
#               <div class="search_name ellipsis">
#                <span class="title">
#                 Resident Evil Requiem
#                </span>
#               </div>
#               <div class="search_platforms">
#                <span class="platform_img win">
#                </span>
#               </div>
#               <div class="search_released responsive_secondrow">
#                26 Feb, 2026
#               </div>
#               <div class="search_reviewscore responsive_secondrow">
#                <span class="search_review_summary positive" data-tooltip-html="Overwhelmingly Positive&lt;br&gt;96% of the 30,938 user reviews for this game are positive.&lt;br&gt;&lt;br&gt;The review score for this product is calculated from reviews written in your language based on your preferences.">
#                </span>
#               </div>
#               <div class="search_price_discount_combined responsive_secondrow" data-price-final="439900">
#                <div class="search_discount_and_price responsive_secondrow">
#                 <div class="discount_block search_discount_block no_discount" data-bundlediscount="0" data-discount="0" data-price-final="439900">
#                  <div class="discount_prices">
#                   <div class="discount_final_price">
#                    ₹4,399.00
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="search_result_row ds_collapse_flag" data-ds-appid="730" data-ds-crtrids="[4]" data-ds-descids="[2,5]" data-ds-itemkey="App_730" data-ds-steam-deck-compat-handled="true" data-ds-tagids="[1663,1774,3859,3878,19,5711,5055]" data-gpnav="item" data-search-page="1" href="https://store.steampowered.com/app/730/CounterStrike_2/?snr=1_7_7_230_150_1" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:730,&quot;public&quot;:1,&quot;v6&quot;:1} );">
#              <div class="search_capsule">
#               <img src="https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/730/capsule_231x87.jpg?t=1749053861"/>
#              </div>
#              <div class="responsive_search_name_combined">
#               <div class="search_name ellipsis">
#                <span class="title">
#                 Counter-Strike 2
#                </span>
#               </div>
#               <div class="search_platforms">
#                <span class="platform_img win">
#                </span>
#                <span class="platform_img linux">
#                </span>
#               </div>
#               <div class="search_released responsive_secondrow">
#                21 Aug, 2012
#               </div>
#               <div class="search_reviewscore responsive_secondrow">
#                <span class="search_review_summary positive" data-tooltip-html="Very Positive&lt;br&gt;86% of the 2,495,013 user reviews for this game are positive.&lt;br&gt;&lt;br&gt;The review score for this product is calculated from reviews written in your language based on your preferences.">
#                </span>
#               </div>
#               <div class="search_price_discount_combined responsive_secondrow" data-price-final="137000">
#                <div class="search_discount_and_price responsive_secondrow">
#                 <div class="discount_block no_discount search_discount_block">
#                  <div class="discount_prices">
#                   <div class="discount_final_price free">
#                    Free
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="search_result_row ds_collapse_flag" data-ds-appid="3065800" data-ds-crtrids="[42567202]" data-ds-itemkey="App_3065800" data-ds-steam-deck-compat-handled="true" data-ds-tagids="[1199779,1775,3859,1774,3942,1663,19]" data-gpnav="item" data-search-page="1" href="https://store.steampowered.com/app/3065800/Marathon/?snr=1_7_7_230_150_1" onmouseout="HideGameHover( this, event, 'global_hover' )" onmouseover="GameHover( this, event, 'global_hover', {&quot;type&quot;:&quot;app&quot;,&quot;id&quot;:3065800,&quot;public&quot;:1,&quot;v6&quot;:1} );">
#              <div class="search_capsule">
#               <img src="https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/3065800/4a77146f41c57cb6d41c984ce27b54c41847678d/capsule_231x87.jpg?t=1772818683"/>
#              </div>
#              <div class="responsive_search_name_combined">
#               <div class="search_name ellipsis">
#                <span class="title">
#                 Marathon
#                </span>
#               </div>
#               <div class="search_platforms">
#                <span class="platform_img win">
#                </span>
#               </div>
#               <div class="search_released responsive_secondrow">
#                5 Mar, 2026
#               </div>
#               <div class="search_reviewscore responsive_secondrow">
#                <span class="search_review_summary positive" data-tooltip-html="Very Positive&lt;br&gt;90% of the 7,769 user reviews for this game are positive.&lt;br&gt;&lt;br&gt;The review score for this product is calculated from reviews written in your language based on your preferences.">
#                </span>
#               </div>
#               <div class="search_price_discount_combined responsive_secondrow" data-price-final="244900">
#                <div class="search_discount_and_price responsive_secondrow">
#                 <div class="discount_block search_discount_block no_discount" data-bundlediscount="0" data-discount="0" data-price-final="244900">
#                  <div class="discount_prices">
#                   <div class="discount_final_price">
#                    ₹2,449.00
#                   </div>
#                  </div>
#                 </div>
#                </div>
# ...
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Telugu
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Tigrinya" data-param="supportedlang" data-value="tigrinya">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Tigrinya" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="tigrinya" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Tigrinya
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Tswana" data-param="supportedlang" data-value="tswana">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Tswana" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="tswana" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Tswana
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Turkmen" data-param="supportedlang" data-value="turkmen">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Turkmen" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="turkmen" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Turkmen
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Urdu" data-param="supportedlang" data-value="urdu">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Urdu" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="urdu" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Urdu
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Uyghur" data-param="supportedlang" data-value="uyghur">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Uyghur" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="uyghur" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Uyghur
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Uzbek" data-param="supportedlang" data-value="uzbek">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Uzbek" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="uzbek" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Uzbek
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Valencian" data-param="supportedlang" data-value="valencian">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Valencian" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="valencian" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Valencian
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Welsh" data-param="supportedlang" data-value="welsh">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Welsh" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="welsh" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Welsh
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Wolof" data-param="supportedlang" data-value="wolof">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Wolof" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="wolof" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Wolof
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Xhosa" data-param="supportedlang" data-value="xhosa">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Xhosa" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="xhosa" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Xhosa
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Yoruba" data-param="supportedlang" data-value="yoruba">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Yoruba" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="yoruba" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Yoruba
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#             <div class="tab_filter_control_row" data-clientside="0" data-loc="Zulu" data-param="supportedlang" data-value="zulu">
#              <span class="tab_filter_control tab_filter_control_include" data-clientside="0" data-loc="Zulu" data-panel='{"focusable":true,"clickOnActivate":true}' data-param="supportedlang" data-value="zulu" role="button">
#               <span class="tab_filter_label_container">
#                <span class="tab_filter_control_checkbox">
#                </span>
#                <span class="tab_filter_control_label">
#                 Zulu
#                </span>
#                <span class="tab_filter_control_count" style="display: none;">
#                </span>
#               </span>
#              </span>
#             </div>
#            </div>
#            <input class="search_filter_suggest" id="LanguageSuggest" type="text"/>
#            <script>
#             $J( '#LanguageFilter_Container' ).tableFilter({ maxvisible: 15, control: '#LanguageSuggest', dataattribute: 'loc', 'defaultText': 'search for more languages' });
#            </script>
#            <div id="search_manage_lang_preferences_btn">
#             <a href="https://store.steampowered.com/account/languagepreferences?snr=1_7_7_230">
#              Manage language preferences
#             </a>
#            </div>
#           </div>
#           <a class="see_all_expander nocollapse_only" href="#" onclick="ExpandOptions(this, 'LanguageFilter_Container'); return false;">
#            See all
#           </a>
#          </div>
#         </div>
#         <div class="clear_ctn" style="clear: both;">
#         </div>
#        </div>
#       </div>
#       <!-- End Main Background -->
#       <div id="hidden_searchform_elements">
#        <!-- in responsive mode, the hidden right column inputs are reparented here so they are part of the form -->
#        <input id="search_snr_value" name="snr" type="hidden" value="1_7_7_230_7"/>
#        <input name="list_of_subs" type="hidden" value=""/>
#        <input id="specials" name="specials" type="hidden" value=""/>
#        <input id="hidef2p" name="hidef2p" type="hidden" value=""/>
#        <input id="filter" name="filter" type="hidden" value=""/>
#        <input name="genre" type="hidden" value=""/>
#        <input name="salepage" type="hidden" value=""/>
#        <input id="publisher" name="publisher" type="hidden" value=""/>
#        <input id="developer" name="developer" type="hidden" value=""/>
#        <input id="manufacturer" name="manufacturer" type="hidden" value=""/>
#        <input id="franchise" name="franchise" type="hidden" value=""/>
#        <input id="search_current_page" name="page" type="hidden" value="1"/>
#       </div>
#      </form>
#     </div>
#     <!-- responsive_page_legacy_content -->
#     <div class="" id="footer_spacer" style="">
#     </div>
#     <div class="" id="footer" role="contentinfo">
#      <div class="footer_content">
#       <div class="rule">
#       </div>
#       <div id="footer_logo_steam">
#        <img alt="Valve Software" border="0" src="https://store.akamai.steamstatic.com/public/images/v6/logo_steam_footer.png"/>
#       </div>
#       <div id="footer_logo">
#        <a href="http://www.valvesoftware.com" rel="" target="_blank">
#         <img alt="Valve Software" border="0" src="https://store.akamai.steamstatic.com/public/images/footerLogo_valve_new.png"/>
#        </a>
#       </div>
#       <div data-panel='{"flow-children":"row"}' id="footer_text">
#        <div>
#         © 2026 Valve Corporation.  All rights reserved.  All trademarks are property of their respective owners in the US and other countries.
#        </div>
#        <div>
#         VAT included in all prices where applicable.
#         <a href="https://store.steampowered.com/privacy_agreement/?snr=1_44_44_" rel="" target="_blank">
#          Privacy Policy
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/legal/?snr=1_44_44_" rel="" target="_blank">
#          Legal
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://help.steampowered.com/faqs/view/10BB-D27A-6378-4436?snr=1_44_44_" rel="" target="_blank">
#          Accessibility
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/subscriber_agreement/?snr=1_44_44_" rel="" target="_blank">
#          Steam Subscriber Agreement
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/steam_refunds/?snr=1_44_44_" rel="" target="_blank">
#          Refunds
#         </a>
#         <span aria-hidden="true">
#          |
#         </span>
#         <a href="https://store.steampowered.com/account/cookiepreferences/?snr=1_44_44_" rel="" target="_blank">
#          Cookies
#         </a>
#        </div>
#        <div class="responsive_optin_link">
#         <div class="btn_medium btnv6_grey_black" onclick="Responsive_RequestMobileView()" role="link">
#          <span>
#           View mobile website
#          </span>
#         </div>
#        </div>
#       </div>
#       <div style="clear: left;">
#       </div>
#       <br/>
#       <div class="rule">
#       </div>
#       <div class="valve_links" data-panel='{"flow-children":"row"}'>
#        <a href="http://www.valvesoftware.com/about" rel="" target="_blank">
#         About Valve
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://www.valvesoftware.com" rel="" target="_blank">
#         Jobs
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://www.steampowered.com/steamworks/" rel="" target="_blank">
#         Steamworks
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://partner.steamgames.com/steamdirect" rel="" target="_blank">
#         Steam Distribution
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://help.steampowered.com/en/?snr=1_44_44_">
#         Support
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://store.steampowered.com/digitalgiftcards/?snr=1_44_44_" rel="" target="_blank">
#         Gift Cards
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://steamcommunity.com/linkfilter/?u=http%3A%2F%2Fwww.facebook.com%2FSteam" rel="noopener" target="_blank">
#         <img alt="Facebook: Steam" src="https://store.akamai.steamstatic.com/public/images/ico/ico_facebook.png"/>
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="http://twitter.com/steam" rel="" target="_blank">
#         <img alt="X: @Steam" src="https://store.akamai.steamstatic.com/public/images/ico/ico_twitter.png"/>
#        </a>
#        <span aria-hidden="true">
#         |
#        </span>
#        <a href="https://steamcommunity.com/linkfilter/?u=https%3A%2F%2Fbsky.app%2Fprofile%2Fsteampowered.com" rel="noopener" target="_blank">
#         <img alt="Bluesky: Steampowered" src="https://store.akamai.steamstatic.com/public/images/ico/ico_bsky.png"/>
#        </a>
#       </div>
#       <div class="extra_space">
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- responsive_page_content -->
#   </div>
#   <!-- responsive_page_frame -->
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
import re
import time

data = []

for start in range(0,2000,50):

    url = f'https://store.steampowered.com/search/results/?query&start={start}&count=50'

    webpage = requests.get(url)

    soup = BeautifulSoup(webpage.text,'lxml')

    cards = soup.find_all('a', class_='search_result_row')

    for card in cards:

        # game name
        name = card.find('span', class_='title').text.strip()

        # release date
        release_tag = card.find('div', class_='search_released')
        release_date = release_tag.text.strip() if release_tag else None

        # price
        price_tag = card.select_one('.discount_final_price, .search_price')
        price = price_tag.text.strip() if price_tag else None

        # game link
        link = card['href']

        # reviews
        review_tag = card.find('span', class_='search_review_summary')

        if review_tag:

            tooltip = review_tag.get('data-tooltip-html','')

            review_count = re.findall(r'\d[\d,]*', tooltip)
            review_count = review_count[0] if review_count else None

            rating_label = BeautifulSoup(tooltip,'lxml').text.split("\n")[0]

        else:
            review_count = None
            rating_label = None


        # OPEN GAME PAGE
        game_page = requests.get(link)

        game_soup = BeautifulSoup(game_page.text,"lxml")

        # developer
        developer_tag = game_soup.find("div", id="developers_list")
        developer = developer_tag.text.strip() if developer_tag else None


        publisher = None
        rows = game_soup.find_all("div", class_="dev_row")

        for row in rows:
            subtitle = row.find("div", class_="subtitle column")

            if subtitle and "Publisher" in subtitle.text:
                publisher = row.find("a").text.strip()
                break


        
        genre_tags = game_soup.select(".details_block a")
        genres = ", ".join([g.text for g in genre_tags]) if genre_tags else None


        data.append({
            'game_name': name,
            'release_date': release_date,
            'price': price,
            'rating_label': rating_label,
            'review_count': review_count,
            'developer': developer,
            'publisher': publisher,
            'genres': genres
        })

        
        time.sleep(1)

    print("scraped_offset:", start)
# Out:
# scraped_offset: 0
# scraped_offset: 50
# scraped_offset: 100
# scraped_offset: 150
# scraped_offset: 200
# scraped_offset: 250
# scraped_offset: 300
# scraped_offset: 350
# scraped_offset: 400
# scraped_offset: 450
# scraped_offset: 500
# scraped_offset: 550
# scraped_offset: 600
# scraped_offset: 650
# scraped_offset: 700
# scraped_offset: 750
# scraped_offset: 800
# scraped_offset: 850
# scraped_offset: 900
# scraped_offset: 950
# scraped_offset: 1000
# scraped_offset: 1050
# scraped_offset: 1100
# scraped_offset: 1150
# scraped_offset: 1200
# scraped_offset: 1250
# scraped_offset: 1300
# scraped_offset: 1350
# scraped_offset: 1400
# scraped_offset: 1450
# scraped_offset: 1500
# scraped_offset: 1550
# scraped_offset: 1600
# scraped_offset: 1650
# scraped_offset: 1700
# scraped_offset: 1750
# scraped_offset: 1800
# scraped_offset: 1850
# scraped_offset: 1900
# scraped_offset: 1950

# %%
import pandas as pd

df = pd.DataFrame(data)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_name     2000 non-null   object
#  1   release_date  2000 non-null   object
#  2   price         1991 non-null   object
#  3   rating_label  1983 non-null   object
#  4   review_count  1983 non-null   object
#  5   developer     1996 non-null   object
#  6   publisher     1967 non-null   object
#  7   genres        1997 non-null   object
# dtypes: object(8)
# memory usage: 125.1+ KB

# %%
df.head()
# Out:
#                game_name  release_date      price  \
# 0       Slay the Spire 2   5 Mar, 2026  ₹1,100.00
# 1  Resident Evil Requiem  26 Feb, 2026  ₹4,399.00
# 2       Counter-Strike 2  21 Aug, 2012       Free
# 3               Marathon   5 Mar, 2026  ₹2,449.00
# 4            ARC Raiders  30 Oct, 2025  ₹2,467.00
#
#                                         rating_label review_count  \
# 0  Overwhelmingly Positive97% of the 13,496 user ...           97
# 1  Overwhelmingly Positive96% of the 34,291 user ...           96
# 2  Very Positive86% of the 2,496,132 user reviews...           86
# 3  Very Positive90% of the 12,119 user reviews fo...           90
# 4  Very Positive86% of the 175,346 user reviews f...           86
#
#           developer         publisher  \
# 0         Mega Crit         Mega Crit
# 1  CAPCOM Co., Ltd.  CAPCOM Co., Ltd.
# 2             Valve             Valve
# 3            Bungie            Bungie
# 4    Embark Studios    Embark Studios
#
#                                               genres
# 0  Indie, Strategy, Early Access, Mega Crit, Mega...
# 1  Action, Adventure, CAPCOM Co., Ltd., CAPCOM Co...
# 2  Action, Free To Play, Valve, Valve, \n\t\t\tVi...
# 3  Action, Bungie, Bungie, \n\t\t\tVisit the webs...
# 4  Action, Embark Studios, Embark Studios, \n\t\t...

# %%
df.to_csv('steam_games.csv')

# %% [markdown]
# **Data preprocessing**

# %%
df = pd.read_csv('steam_games.csv')

# %%
df['game_name'].duplicated().sum()
# Out:
# 17

# %%
df[df['game_name'].duplicated(keep=False)]
# Out:
#       Unnamed: 0                                          game_name  \
# 146          146              Age of Empires II: Definitive Edition
# 1199        1199                                      Just Cause™ 3
# 1206        1206                                      Just Cause™ 3
# 1233        1233                                     Scrap Mechanic
# 1239        1239                        Need for Speed™ Most Wanted
# 1241        1241                  A Game About Feeding A Black Hole
# 1242        1242                                              Forts
# 1249        1249                             Marvel's Midnight Suns
# 1250        1250                             Marvel's Midnight Suns
# 1252        1252                                     Scrap Mechanic
# 1253        1253                  A Game About Feeding A Black Hole
# 1255        1255                                              Forts
# 1285        1285                                          Unpacking
# 1298        1298  Expansion - Hearts of Iron IV: No Compromise, ...
# 1301        1301                                          Unpacking
# 1304        1304  Expansion - Hearts of Iron IV: No Compromise, ...
# 1306        1306                        Need for Speed™ Most Wanted
# 1447        1447                                         WonderKing
# 1463        1463                                 OCTOPATH TRAVELER™
# 1484        1484               FIVE NIGHTS AT FREDDY'S: HELP WANTED
# 1489        1489                                         WonderKing
# 1496        1496                    Danganronpa V3: Killing Harmony
# 1501        1501               FIVE NIGHTS AT FREDDY'S: HELP WANTED
# 1502        1502                                 OCTOPATH TRAVELER™
# 1508        1508                    Danganronpa V3: Killing Harmony
# 1539        1539              Age of Empires II: Definitive Edition
# 1593        1593                                     Kin and Quarry
# 1598        1598                   Songs of Conquest - Rise Eternal
# 1599        1599                     Cult of the Lamb: Heretic Pack
# 1600        1600                     Cult of the Lamb: Heretic Pack
# 1603        1603                                     Kin and Quarry
# 1610        1610                   Songs of Conquest - Rise Eternal
# 1749        1749                                        Cozy Island
# 1750        1750                                        Cozy Island
#
#       release_date      price  \
# 146   14 Nov, 2019  ₹1,399.00
# 1199  30 Nov, 2015    ₹399.00
# 1206  30 Nov, 2015    ₹399.00
# 1233  19 Jan, 2016    ₹565.00
# 1239  18 Jun, 2020    ₹999.00
# 1241  15 Dec, 2025    ₹345.00
# 1242  19 Apr, 2017    ₹479.00
# 1249   1 Dec, 2022    ₹918.00
# 1250   1 Dec, 2022    ₹918.00
# 1252  19 Jan, 2016    ₹565.00
# 1253  15 Dec, 2025    ₹345.00
# 1255  19 Apr, 2017    ₹479.00
# 1285   1 Nov, 2021    ₹529.00
# 1298  25 Sep, 2025  ₹1,859.00
# 1301   1 Nov, 2021    ₹529.00
# 1304  25 Sep, 2025  ₹1,859.00
# 1306  18 Jun, 2020    ₹999.00
# 1447  12 Jan, 2026       Free
# 1463   7 Jun, 2019  ₹4,250.00
# 1484  28 May, 2019    ₹699.00
# 1489  12 Jan, 2026       Free
# 1496  25 Sep, 2017    ₹899.00
# 1501  28 May, 2019    ₹699.00
# 1502   7 Jun, 2019  ₹4,250.00
# 1508  25 Sep, 2017    ₹899.00
# 1539  14 Nov, 2019  ₹1,399.00
# 1593  16 Jan, 2026    ₹480.00
# 1598   5 Mar, 2026    ₹369.00
# 1599  24 Apr, 2023    ₹250.00
# 1600  24 Apr, 2023    ₹250.00
# 1603  16 Jan, 2026    ₹480.00
# 1610   5 Mar, 2026    ₹369.00
# 1749  21 Sep, 2025    ₹450.00
# 1750  21 Sep, 2025    ₹450.00
#
#                                            rating_label  review_count  \
# 146   Overwhelmingly Positive95% of the 59,282 user ...          95.0
# 1199  Very Positive86% of the 44,728 user reviews fo...          86.0
# 1206  Very Positive86% of the 44,728 user reviews fo...          86.0
# 1233  Very Positive90% of the 45,677 user reviews fo...          90.0
# 1239  Mostly Positive74% of the 7,949 user reviews f...          74.0
# 1241  Very Positive89% of the 1,423 user reviews for...          89.0
# 1242  Very Positive93% of the 8,432 user reviews for...          93.0
# 1249  Very Positive83% of the 11,238 user reviews fo...          83.0
# 1250  Very Positive83% of the 11,238 user reviews fo...          83.0
# 1252  Very Positive90% of the 45,677 user reviews fo...          90.0
# 1253  Very Positive89% of the 1,423 user reviews for...          89.0
# 1255  Very Positive93% of the 8,433 user reviews for...          93.0
# 1285  Very Positive93% of the 21,921 user reviews fo...          93.0
# 1298  Mostly Negative33% of the 1,479 user reviews f...          33.0
# 1301  Very Positive93% of the 21,921 user reviews fo...          93.0
# 1304  Mostly Negative33% of the 1,479 user reviews f...          33.0
# 1306  Mostly Positive74% of the 7,949 user reviews f...          74.0
# 1447  Mixed44% of the 289 user reviews for this game...          44.0
# 1463  Very Positive86% of the 4,823 user reviews for...          86.0
# 1484  Overwhelmingly Positive95% of the 7,420 user r...          95.0
# 1489  Mixed44% of the 289 user reviews for this game...          44.0
# 1496  Very Positive88% of the 9,025 user reviews for...          88.0
# 1501  Overwhelmingly Positive95% of the 7,420 user r...          95.0
# 1502  Very Positive86% of the 4,823 user reviews for...          86.0
# 1508  Very Positive88% of the 9,025 user reviews for...          88.0
# 1539  Very Positive94% of the 154,372 user reviews f...          94.0
# 1593  Mostly Positive76% of the 301 user reviews for...          76.0
# 1598  Positive100% of the 15 user reviews for this g...         100.0
# 1599  Very Positive96% of the 131 user reviews for t...          96.0
# 1600  Very Positive96% of the 131 user reviews for t...          96.0
# 1603  Mostly Positive76% of the 301 user reviews for...          76.0
# 1610  Positive100% of the 15 user reviews for this g...         100.0
# 1749  Very Positive92% of the 2,137 user reviews for...          92.0
# 1750  Very Positive92% of the 2,137 user reviews for...          92.0
#
#                                               developer  \
# 146   World's Edge, Forgotten Empires, CaptureAge, T...
# 1199                                  Avalanche Studios
# 1206                                  Avalanche Studios
# 1233                                       Axolot Games
# 1239                                    Criterion Games
# 1241                               Aarimous, Thornityco
# 1242                                    EarthWork Games
# 1249                                      Firaxis Games
# 1250                                      Firaxis Games
# 1252                                       Axolot Games
# 1253                               Aarimous, Thornityco
# 1255                                    EarthWork Games
# 1285                                         Witch Beam
# 1298                         Paradox Development Studio
# 1301                                         Witch Beam
# 1304                         Paradox Development Studio
# 1306                                    Criterion Games
# 1447                                      dreamideasoft
# 1463                         Square Enix, ACQUIRE Corp.
# 1484                                 Steel Wool Studios
# 1489                                      dreamideasoft
# 1496                           Spike Chunsoft Co., Ltd.
# 1501                                 Steel Wool Studios
# 1502                         Square Enix, ACQUIRE Corp.
# 1508                           Spike Chunsoft Co., Ltd.
# 1539                                                NaN
# 1593                                     The Fox Knocks
# 1598                                         Lavapotion
# 1599                                    Massive Monster
# 1600                                    Massive Monster
# 1603                                     The Fox Knocks
# 1610                                         Lavapotion
# 1749                                    LazyFish Studio
# 1750                                    LazyFish Studio
#
#                      publisher  \
# 146          Xbox Game Studios
# 1199               Square Enix
# 1206               Square Enix
# 1233              Axolot Games
# 1239           Electronic Arts
# 1241                  Aarimous
# 1242           EarthWork Games
# 1249                        2K
# 1250                        2K
# 1252              Axolot Games
# 1253                  Aarimous
# 1255           EarthWork Games
# 1285              Humble Games
# 1298       Paradox Interactive
# 1301              Humble Games
# 1304       Paradox Interactive
# 1306           Electronic Arts
# 1447                wondersoft
# 1463               Square Enix
# 1484                ScottGames
# 1489                wondersoft
# 1496  Spike Chunsoft Co., Ltd.
# 1501                ScottGames
# 1502               Square Enix
# 1508  Spike Chunsoft Co., Ltd.
# 1539                       NaN
# 1593            The Fox Knocks
# 1598   Coffee Stain Publishing
# 1599          Devolver Digital
# 1600          Devolver Digital
# 1603            The Fox Knocks
# 1610   Coffee Stain Publishing
# 1749           LazyFish Studio
# 1750           LazyFish Studio
#
#                                                  genres
# 146   Strategy, World's Edge, Forgotten Empires, Cap...
# 1199  Action, Adventure, Avalanche Studios, Square E...
# 1206  Action, Adventure, Avalanche Studios, Square E...
# 1233  Action, Adventure, Indie, Simulation, Early Ac...
# 1239  Action, Adventure, Racing, Criterion Games, El...
# 1241  Casual, Indie, Aarimous, Thornityco, Aarimous,...
# 1242  Action, Indie, Strategy, EarthWork Games, Eart...
# 1249  RPG, Strategy, Firaxis Games, 2K, Marvel's Mid...
# 1250  RPG, Strategy, Firaxis Games, 2K, Marvel's Mid...
# 1252  Action, Adventure, Indie, Simulation, Early Ac...
# 1253  Casual, Indie, Aarimous, Thornityco, Aarimous,...
# 1255  Action, Indie, Strategy, EarthWork Games, Eart...
# 1285  Casual, Indie, Simulation, Witch Beam, Humble ...
# 1298  Simulation, Strategy, Paradox Development Stud...
# 1301  Casual, Indie, Simulation, Witch Beam, Humble ...
# 1304  Simulation, Strategy, Paradox Development Stud...
# 1306  Action, Adventure, Racing, Criterion Games, El...
# 1447  Massively Multiplayer, RPG, Free To Play, drea...
# 1463  RPG, Square Enix, ACQUIRE Corp., Square Enix, ...
# 1484  Action, Casual, Steel Wool Studios, ScottGames...
# 1489  Massively Multiplayer, RPG, Free To Play, drea...
# 1496  Adventure, Spike Chunsoft Co., Ltd., Spike Chu...
# 1501  Action, Casual, Steel Wool Studios, ScottGames...
# 1502  RPG, Square Enix, ACQUIRE Corp., Square Enix, ...
# 1508  Adventure, Spike Chunsoft Co., Ltd., Spike Chu...
# 1539  Strategy, World's Edge, Forgotten Empires, Cap...
# 1593  Indie, The Fox Knocks, The Fox Knocks, \n\t\t\...
# 1598  Adventure, RPG, Strategy, Lavapotion, Coffee S...
# 1599  Action, Adventure, Indie, Strategy, Massive Mo...
# 1600  Action, Adventure, Indie, Strategy, Massive Mo...
# 1603  Indie, The Fox Knocks, The Fox Knocks, \n\t\t\...
# 1610  Adventure, RPG, Strategy, Lavapotion, Coffee S...
# 1749  Adventure, Casual, Indie, LazyFish Studio, Laz...
# 1750  Adventure, Casual, Indie, LazyFish Studio, Laz...

# %%
df = df.drop_duplicates(subset='game_name')

# %%
df['game_name'].duplicated().sum()
# Out:
# 0

# %%
df['price'] = df['price'].str.replace('₹','')
df['price'] = df['price'].str.replace(',','')
df['price'] = df['price'].str.replace('Free','0')
df['price'] = df['price'].astype(float)

# %%
# convert release_date to datetime
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# extract year and month
df['release_year'] = df['release_date'].dt.year
df['release_month'] = df['release_date'].dt.month

# remove rows where date was invalid
df = df.dropna(subset=['release_year'])

# convert to integers
df['release_year'] = df['release_year'].astype(int)
df['release_month'] = df['release_month'].astype(int)

# drop original column
df = df.drop(columns=['release_date'])

# %%
df['review_sentiment'] = df['rating_label'].str.extract(r'^(.*?)(?=\d)')

# %%
df['review_score'] = df['rating_label'].str.extract(r'(\d+)%')

df['review_score'] = pd.to_numeric(df['review_score'], errors='coerce')

df = df.dropna(subset=['review_score'])

df['review_score'] = df['review_score'].astype(int)

# %%
df['review_count'] = df['rating_label'].str.extract(r'([\d,]+)\suser')
df['review_count'] = df['review_count'].str.replace(',', '')
df['review_count'] = df['review_count'].astype(int)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# game_name            0
# price                6
# rating_label         0
# review_count         0
# developer            1
# publisher           30
# genres               1
# release_year         0
# release_month        0
# review_sentiment     0
# review_score         0
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0'] , inplace = True)

# %%
df.drop(columns = ['rating_label'] , inplace = True)

# %%
top_devs = df['developer'].value_counts().nlargest(20).index

df['developer'] = df['developer'].apply(lambda x: x if x in top_devs else 'Other')

# %%
top_pubs = df['publisher'].value_counts().nlargest(20).index

df['publisher'] = df['publisher'].apply(lambda x: x if x in top_pubs else 'Other')

# %%
df['genres'] = df['genres'].str.split(',').str[:3]
df['genres'] = df['genres'].apply(lambda x: ','.join(x) if isinstance(x,list) else x)

# %%
valid_genres = [
'Action','Adventure','RPG','Strategy','Simulation','Sports',
'Racing','Casual','Indie','Free To Play','Massively Multiplayer',
'Early Access','Puzzle','Horror','Platformer','Shooter'
]

def clean_genres(genres):
    
    if pd.isna(genres):
        return None
        
    items = [g.strip() for g in genres.split(',')]
    
    filtered = [g for g in items if g in valid_genres]
    
    return ','.join(filtered)

df['genres'] = df['genres'].apply(clean_genres)

# %%
df.dropna(subset = ['genres'],inplace = True)

# %%
df['price'] = df['price'].fillna(0)

# %%
df['log_review_count'] = np.log1p(df['review_count'])

# %% [markdown]
# Since predicting exact review counts proved difficult due to the inherent noise in popularity metrics, the target variable was re-engineered into a multi-class classification problem. The continuous log-transformed review count was binned into four balanced popularity tiers — Low, Medium, High, and Viral — using quartile-based segmentation (pd.qcut), ensuring equal class distribution. This transformation makes the prediction task more robust and practically meaningful, shifting the question from "how many reviews will a game get?" to "how popular will this game be?" — a more actionable framing.

# %%
df['popularity_tier'] = pd.qcut(
    df['log_review_count'],
    q=4,
    labels=['Low','Medium','High','Viral']
)

# %%
df['popularity_tier'].value_counts()
# Out:
# popularity_tier
# Low       491
# Medium    491
# High      491
# Viral     491
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                game_name   price  review_count         developer  \
# 0       Slay the Spire 2  1100.0         13496             Other
# 1  Resident Evil Requiem  4399.0         34291  CAPCOM Co., Ltd.
# 2       Counter-Strike 2     0.0       2496132             Valve
# 3               Marathon  2449.0         12119             Other
# 4            ARC Raiders  2467.0        175346             Other
#
#           publisher                       genres  release_year  release_month  \
# 0             Other  Indie,Strategy,Early Access          2026              3
# 1  CAPCOM Co., Ltd.             Action,Adventure          2026              2
# 2             Valve          Action,Free To Play          2012              8
# 3             Other                       Action          2026              3
# 4             Other                       Action          2025             10
#
#           review_sentiment  review_score  log_review_count popularity_tier
# 0  Overwhelmingly Positive            97          9.510223            High
# 1  Overwhelmingly Positive            96         10.442667           Viral
# 2            Very Positive            86         14.730253           Viral
# 3            Very Positive            90          9.402612            High
# 4            Very Positive            86         12.074522           Viral

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1964 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game_name         1964 non-null   object
#  1   price             1964 non-null   float64
#  2   review_count      1964 non-null   int32
#  3   developer         1964 non-null   object
#  4   publisher         1964 non-null   object
#  5   genres            1964 non-null   object
#  6   release_year      1964 non-null   int32
#  7   release_month     1964 non-null   int32
#  8   review_sentiment  1964 non-null   object
#  9   review_score      1964 non-null   int32
#  10  log_review_count  1964 non-null   float64
#  11  popularity_tier   1964 non-null   category
# dtypes: category(1), float64(2), int32(4), object(5)
# memory usage: 155.6+ KB

# %%
df.isnull().sum()
# Out:
# game_name           0
# price               0
# review_count        0
# developer           0
# publisher           0
# genres              0
# release_year        0
# release_month       0
# review_sentiment    0
# review_score        0
# log_review_count    0
# popularity_tier     0
# dtype: int64

# %%
df.to_csv('steam_games_cleaned.csv',index=False)

# %%
df2 = pd.read_csv('steam_games_cleaned.csv')

# %%
df2.shape
# Out:
# (1964, 12)

# %%
df2.columns
# Out:
# Index(['game_name', 'price', 'review_count', 'developer', 'publisher',
#        'genres', 'release_year', 'release_month', 'review_sentiment',
#        'review_score', 'log_review_count', 'popularity_tier'],
#       dtype='object')
